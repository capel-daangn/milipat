# %%
import pandas as pd

df_origin = pd.read_csv("방위사업청_보유_특허목록_20221231.csv", index_col="연번")
df_origin
# Out:
#                                                 발명의명칭             출원번호  \
# 연번
# 1   이중곡률반경 형성체 리브를 가지는 항공기 타이어(Aircraft Tire with ...  10-2004-0048382
# 2   숄더그루브 깊이를 축소시킨 소형 항공기 타이어(Small-sized Aircraft...  10-2004-0048381
# 3   포드 인양장치 하중시험용 치구(load testing tool for pod lif...   10-2012-064850
# 4                                       방독면(GAS-MASK)  10-2012-0133170
# 5                                       방독면(GAS-MASK)  10-2012-0133138
# ..                                                ...              ...
# 78                          회전체의 센서 데이터를 계측하여 전송하는 방법  10-2012-0046179
# 79          비행시험 데이터를 이용한 HQS 모델링과 튜닝을 위한 장치 및 그 제어방법  10-2013-0028687
# 80                                          탄약통 고정 장치  10-2013-0059589
# 81                         헬리콥터의 카고훅 하중시현시스템 및 그 제어방법  10-2013-0091447
# 82         하중 보정 기능이 구비된 헬리콥터의 카고훅 하중시현 시스템 및 그 제어 방법  10-2013-0091448
#
#         출원일자         등록번호      등록일자  상태
# 연번
# 1    6/25/04  1.00513E+12   8/31/05  등록
# ...

# %%
df_origin.to_json('방위사업청_보유_특허목록_20221231.json', orient="records", force_ascii=False)
